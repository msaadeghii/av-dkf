# %%
import pandas as pd

# %%
df = pd.read_csv('metrics.csv')
df
# Out:
#      File name Noise Type  Noise SNR     SI-SDR      STOI      PESQ
# 0       si1148     Babble          5  -0.194514  0.486535  1.206477
# 1          sa1        Car          0   5.750594  0.593135  1.137974
# 2       si1021       Cafe         -5  -4.857781  0.396223  1.160996
# 3       si1097     Babble         -5  -7.324541  0.484014  1.179915
# 4       si1122       Cafe        -10 -13.444438  0.348077  1.098495
# ...        ...        ...        ...        ...       ...       ...
# 1345    si1021     Street          0   2.479618  0.579753  1.156522
# 1346       sa2         LR          5   5.404095  0.856934  1.206282
# 1347       sa2      White          0   0.928902  0.692196  1.086200
# 1348    si1024     Babble         10   7.914862  0.779808  1.585785
# 1349    si1024        Car        -10  -3.963279  0.411287  1.089651
#
# [1350 rows x 6 columns]

# %%
df.groupby(['Noise Type','Noise SNR']).median(numeric_only=True)
# Out:
#                          SI-SDR      STOI      PESQ
# Noise Type Noise SNR
# Babble     -10       -11.951075  0.332763  1.103336
#            -5         -5.801058  0.415182  1.121796
#             0         -0.780292  0.538528  1.175016
#             5          4.015554  0.654233  1.297884
#             10         7.914862  0.734621  1.546841
# Cafe       -10       -11.045589  0.354672  1.112876
#            -5         -5.488874  0.437831  1.149182
#             0         -0.600117  0.553156  1.209340
#             5          4.315408  0.660412  1.334259
#             10         8.838793  0.758496  1.504794
# Car        -10        -5.900749  0.320769  1.120745
#            -5         -3.163327  0.350329  1.119722
#             0         -0.769010  0.446373  1.179963
#             5          2.884632  0.548476  1.256196
#             10         4.828220  0.654154  1.372570
# LR         -10        -9.241916  0.447136  1.082001
#            -5         -4.699315  0.546825  1.112159
# ...
